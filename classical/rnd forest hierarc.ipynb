# %%
import pandas as pd

# %% [markdown]
# # First level

# %%
df_train = pd.read_pickle("./df_train_W_meta_metrics.pkl")
df_train
# Out:
#       nodes  edges  ratio_n_m  ratio_m_n   density  min_degree  max_degree  \
# 0        19     11   1.727273   0.578947  0.064327           0           3
# 1        34    130   0.261538   3.823529  0.231729           3          12
# 2        68    364   0.186813   5.352941  0.159789           3          18
# 3        58    122   0.475410   2.103448  0.073805           1          10
# 4        96    131   0.732824   1.364583  0.028728           0           9
# ...     ...    ...        ...        ...       ...         ...         ...
# 4495     25      2  12.500000   0.080000  0.006667           0           1
# 4496     98    202   0.485149   2.061224  0.042499           0          12
# 4497     51     71   0.718310   1.392157  0.055686           0           6
# 4498    137   1547   0.088559  11.291971  0.166058          12          33
# 4499    124   1557   0.079640  12.556452  0.204170          15          41
#
#       mean_degree  median_degree  q0.25_degree  ...  entropy_degree  \
# 0        1.157895            1.0           0.0  ...        1.871019
# 1        7.647059            7.0           6.0  ...        3.051602
# 2       10.705882           11.0           9.0  ...        3.374558
# 3        4.206897            4.0           3.0  ...        2.907696
# 4        2.729167            2.0           1.0  ...        2.686679
# ...           ...            ...           ...  ...             ...
# 4495     0.160000            0.0           0.0  ...        0.634310
# 4496     4.122449            4.0           3.0  ...        3.017961
# 4497     2.784314            3.0           2.0  ...        2.478563
# 4498    22.583942           23.0          19.0  ...        4.022536
# 4499    25.112903           25.0          22.0  ...        4.122713
#
#       normalized_min_clique_size  normalized_max_clique_size  \
# 0                       0.052632                    0.157895
# 1                       0.029412                    0.117647
# 2                       0.014706                    0.058824
# 3                       0.017241                    0.051724
# 4                       0.010417                    0.031250
# ...                          ...                         ...
# 4495                    0.040000                    0.080000
# 4496                    0.010204                    0.030612
# 4497                    0.019608                    0.039216
# 4498                    0.007299                    0.036496
# 4499                    0.008065                    0.040323
#
#       normalized_median_clique_size  normalized_q0.25_clique_size  \
# 0                          0.052632                      0.052632
# 1                          0.058824                      0.058824
# 2                          0.029412                      0.029412
# 3                          0.034483                      0.017241
# 4                          0.020833                      0.010417
# ...                             ...                           ...
# 4495                       0.040000                      0.040000
# 4496                       0.020408                      0.010204
# 4497                       0.039216                      0.019608
# 4498                       0.021898                      0.014599
# 4499                       0.024194                      0.016129
#
#       normalized_q0.75_clique_size  \
# 0                         0.105263
# 1                         0.088235
# 2                         0.044118
# 3                         0.034483
# 4                         0.020833
# ...                            ...
# 4495                      0.040000
# 4496                      0.020408
# 4497                      0.039216
# 4498                      0.021898
# 4499                      0.024194
#
#       normalized_variation_coefficient_clique_size  \
# 0                                         0.397478
# 1                                         0.324626
# 2                                         0.301528
# 3                                         0.319693
# 4                                         0.330712
# ...                                            ...
# 4495                                      0.248475
# 4496                                      0.305481
# 4497                                      0.313072
# 4498                                      0.261367
# 4499                                      0.257049
#
#       normalized_entropy_clique_size               target_time  \
# 0                           0.059110                       dfs
# 1                           0.046827         best_first_search
# 2                           0.022069         best_first_search
# 3                           0.020953         best_first_search
# 4                           0.011580      bidirectional_search
# ...                              ...                       ...
# 4495                        0.015238  randomized_shortest_path
# 4496                        0.011343      bidirectional_search
# 4497                        0.019226                       dfs
# 4498                        0.010864         best_first_search
# 4499                        0.012609         best_first_search
#
#                   target_space
# 0                          dfs
# 1            best_first_search
# 2            best_first_search
# 3                        astar
# 4         bidirectional_search
# ...                        ...
# 4495  randomized_shortest_path
# 4496         best_first_search
# 4497         best_first_search
# 4498                     astar
# 4499         best_first_search
#
# [4500 rows x 22 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 22 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   nodes                                         4500 non-null   int64
#  1   edges                                         4500 non-null   int64
#  2   ratio_n_m                                     4500 non-null   float64
#  3   ratio_m_n                                     4500 non-null   float64
#  4   density                                       4500 non-null   float64
#  5   min_degree                                    4500 non-null   int64
#  6   max_degree                                    4500 non-null   int64
#  7   mean_degree                                   4500 non-null   float64
#  8   median_degree                                 4500 non-null   float64
#  9   q0.25_degree                                  4500 non-null   float64
#  10  q0.75_degree                                  4500 non-null   float64
#  11  variation_coefficient_degree                  4500 non-null   float64
#  12  entropy_degree                                4500 non-null   float64
#  13  normalized_min_clique_size                    4500 non-null   float64
#  14  normalized_max_clique_size                    4500 non-null   float64
#  15  normalized_median_clique_size                 4500 non-null   float64
#  16  normalized_q0.25_clique_size                  4500 non-null   float64
#  17  normalized_q0.75_clique_size                  4500 non-null   float64
#  18  normalized_variation_coefficient_clique_size  4500 non-null   float64
#  19  normalized_entropy_clique_size                4500 non-null   float64
#  20  target_time                                   4500 non-null   object
#  21  target_space                                  4500 non-null   object
# dtypes: float64(16), int64(4), object(2)
# memory usage: 773.6+ KB

# %% [markdown]
# Encode labels

# %%
found_labels_in_df = df_train.iloc[:, 20].squeeze().unique().tolist()
print("Found labels:", found_labels_in_df)

encoder_labels = {'bidirectional_search': 1,
                  'best_first_search': 0,
                  'dfs': 1, 'dijkstra': 1,
                  'bfs': 1,
                  'randomized_shortest_path': 1,
                  'astar': 1}

df_train.replace({"target_time": encoder_labels}, inplace=True)

df_train.head()
# Out:
# Found labels: ['dfs', 'best_first_search', 'bidirectional_search', 'bfs', 'dijkstra', 'randomized_shortest_path', 'astar']
#    nodes  edges  ratio_n_m  ratio_m_n   density  min_degree  max_degree  \
# 0     19     11   1.727273   0.578947  0.064327           0           3
# 1     34    130   0.261538   3.823529  0.231729           3          12
# 2     68    364   0.186813   5.352941  0.159789           3          18
# 3     58    122   0.475410   2.103448  0.073805           1          10
# 4     96    131   0.732824   1.364583  0.028728           0           9
#
#    mean_degree  median_degree  q0.25_degree  ...  entropy_degree  \
# 0     1.157895            1.0           0.0  ...        1.871019
# 1     7.647059            7.0           6.0  ...        3.051602
# 2    10.705882           11.0           9.0  ...        3.374558
# 3     4.206897            4.0           3.0  ...        2.907696
# 4     2.729167            2.0           1.0  ...        2.686679
#
#    normalized_min_clique_size  normalized_max_clique_size  \
# 0                    0.052632                    0.157895
# 1                    0.029412                    0.117647
# 2                    0.014706                    0.058824
# 3                    0.017241                    0.051724
# 4                    0.010417                    0.031250
#
#    normalized_median_clique_size  normalized_q0.25_clique_size  \
# 0                       0.052632                      0.052632
# 1                       0.058824                      0.058824
# 2                       0.029412                      0.029412
# 3                       0.034483                      0.017241
# 4                       0.020833                      0.010417
#
#    normalized_q0.75_clique_size  normalized_variation_coefficient_clique_size  \
# 0                      0.105263                                      0.397478
# 1                      0.088235                                      0.324626
# 2                      0.044118                                      0.301528
# 3                      0.034483                                      0.319693
# 4                      0.020833                                      0.330712
#
#    normalized_entropy_clique_size  target_time          target_space
# 0                        0.059110            1                   dfs
# 1                        0.046827            0     best_first_search
# 2                        0.022069            0     best_first_search
# 3                        0.020953            0                 astar
# 4                        0.011580            1  bidirectional_search
#
# [5 rows x 22 columns]

# %%
print(len(df_train))
df_train.dropna(inplace=True)
print(len(df_train))
# Out:
# 4500
# 4500

# %%
from sklearn.ensemble import RandomForestClassifier

rfclassif=RandomForestClassifier(n_estimators=200,criterion="entropy",max_depth=10, bootstrap=True, n_jobs=4)
rfclassif.fit(df_train.iloc[:,:20].to_numpy(), df_train.iloc[:,20].to_numpy())
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=200,
#                        n_jobs=4)

# %% [markdown]
# ## Test

# %%
test_df = pd.read_pickle("./df_test_W_meta_metrics.pkl")
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 22 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   nodes                                         500 non-null    int64
#  1   edges                                         500 non-null    int64
#  2   ratio_n_m                                     500 non-null    float64
#  3   ratio_m_n                                     500 non-null    float64
#  4   density                                       500 non-null    float64
#  5   min_degree                                    500 non-null    int64
#  6   max_degree                                    500 non-null    int64
#  7   mean_degree                                   500 non-null    float64
#  8   median_degree                                 500 non-null    float64
#  9   q0.25_degree                                  500 non-null    float64
#  10  q0.75_degree                                  500 non-null    float64
#  11  variation_coefficient_degree                  500 non-null    float64
#  12  entropy_degree                                500 non-null    float64
#  13  normalized_min_clique_size                    500 non-null    float64
#  14  normalized_max_clique_size                    500 non-null    float64
#  15  normalized_median_clique_size                 500 non-null    float64
#  16  normalized_q0.25_clique_size                  500 non-null    float64
#  17  normalized_q0.75_clique_size                  500 non-null    float64
#  18  normalized_variation_coefficient_clique_size  500 non-null    float64
#  19  normalized_entropy_clique_size                500 non-null    float64
#  20  target_time                                   500 non-null    object
#  21  target_space                                  500 non-null    object
# dtypes: float64(16), int64(4), object(2)
# memory usage: 86.1+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 22 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   nodes                                         500 non-null    int64
#  1   edges                                         500 non-null    int64
#  2   ratio_n_m                                     500 non-null    float64
#  3   ratio_m_n                                     500 non-null    float64
#  4   density                                       500 non-null    float64
#  5   min_degree                                    500 non-null    int64
#  6   max_degree                                    500 non-null    int64
#  7   mean_degree                                   500 non-null    float64
#  8   median_degree                                 500 non-null    float64
#  9   q0.25_degree                                  500 non-null    float64
#  10  q0.75_degree                                  500 non-null    float64
#  11  variation_coefficient_degree                  500 non-null    float64
#  12  entropy_degree                                500 non-null    float64
#  13  normalized_min_clique_size                    500 non-null    float64
#  14  normalized_max_clique_size                    500 non-null    float64
#  15  normalized_median_clique_size                 500 non-null    float64
#  16  normalized_q0.25_clique_size                  500 non-null    float64
#  17  normalized_q0.75_clique_size                  500 non-null    float64
#  18  normalized_variation_coefficient_clique_size  500 non-null    float64
#  19  normalized_entropy_clique_size                500 non-null    float64
#  20  target_time                                   500 non-null    object
#  21  target_space                                  500 non-null    object
# dtypes: float64(16), int64(4), object(2)
# memory usage: 86.1+ KB

# %%
test_df.replace({"target_time":encoder_labels}, inplace=True)
test_df.head()
# Out:
#    nodes  edges  ratio_n_m  ratio_m_n   density  min_degree  max_degree  \
# 0     41     85   0.482353   2.073171  0.103659           1          10
# 1     31     52   0.596154   1.677419  0.111828           1           6
# 2     30     83   0.361446   2.766667  0.190805           2          10
# 3    187   3046   0.061392  16.288770  0.175148          21          46
# 4    105    141   0.744681   1.342857  0.025824           0           9
#
#    mean_degree  median_degree  q0.25_degree  ...  entropy_degree  \
# 0     4.146341            4.0           3.0  ...        2.737474
# 1     3.354839            3.0           2.0  ...        2.543065
# 2     5.533333            5.5           4.0  ...        2.806239
# 3    32.577540           33.0          29.5  ...        4.143077
# 4     2.685714            2.0           1.0  ...        2.702194
#
#    normalized_min_clique_size  normalized_max_clique_size  \
# 0                    0.024390                    0.073171
# 1                    0.032258                    0.096774
# 2                    0.033333                    0.100000
# 3                    0.005348                    0.026738
# 4                    0.009524                    0.028571
#
#    normalized_median_clique_size  normalized_q0.25_clique_size  \
# 0                       0.048780                      0.024390
# 1                       0.064516                      0.032258
# 2                       0.066667                      0.066667
# 3                       0.016043                      0.010695
# 4                       0.019048                      0.009524
#
#    normalized_q0.75_clique_size  normalized_variation_coefficient_clique_size  \
# 0                      0.048780                                      0.329137
# 1                      0.064516                                      0.350882
# 2                      0.066667                                      0.322118
# 3                      0.016043                                      0.246461
# 4                      0.019048                                      0.330766
#
#    normalized_entropy_clique_size  target_time              target_space
# 0                        0.031053            0         best_first_search
# 1                        0.042649            0         best_first_search
# 2                        0.045542            1         best_first_search
# 3                        0.008123            0  randomized_shortest_path
# 4                        0.010532            1      bidirectional_search
#
# [5 rows x 22 columns]

# %%
print(len(test_df))
test_df.dropna(inplace=True)
print(len(test_df))
# Out:
# 500
# 500

# %%
y_tilde = rfclassif.predict(test_df.iloc[:,0:20].to_numpy())

# %%
y = test_df.iloc[:,20]

# %%
acc=sum([1 for x,y in zip(y_tilde, y) if x==y])/len(y)
print(f"Accuracy: {acc*100}%")
# Out:
# Accuracy: 85.6%

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score

c_mat=confusion_matrix(y,y_tilde, normalize="true")
disp=ConfusionMatrixDisplay(c_mat)
disp.plot()

print("F1-score:", f1_score(y, y_tilde, average="weighted"))
# Out:
# F1-score: 0.8553963683375448

# %%
import pickle
from datetime import datetime as dt
ts = dt.now().strftime("%Y-%m-%d-%H-%M")
print(ts)
with open(f"./models/{ts}_{int(acc*100)}accuracy_random_forest_first_level.pkl", mode="wb") as f:
    pickle.dump(rfclassif, f)
# Out:
# 2023-12-19-18-54

# %% [markdown]
# ---
#
# # Second level

# %%
df_train = pd.read_pickle("./df_train_W_meta_metrics.pkl")
df_train
# Out:
#       nodes  edges  ratio_n_m  ratio_m_n   density  min_degree  max_degree  \
# 0        19     11   1.727273   0.578947  0.064327           0           3
# 1        34    130   0.261538   3.823529  0.231729           3          12
# 2        68    364   0.186813   5.352941  0.159789           3          18
# 3        58    122   0.475410   2.103448  0.073805           1          10
# 4        96    131   0.732824   1.364583  0.028728           0           9
# ...     ...    ...        ...        ...       ...         ...         ...
# 4495     25      2  12.500000   0.080000  0.006667           0           1
# 4496     98    202   0.485149   2.061224  0.042499           0          12
# 4497     51     71   0.718310   1.392157  0.055686           0           6
# 4498    137   1547   0.088559  11.291971  0.166058          12          33
# 4499    124   1557   0.079640  12.556452  0.204170          15          41
#
#       mean_degree  median_degree  q0.25_degree  ...  entropy_degree  \
# 0        1.157895            1.0           0.0  ...        1.871019
# 1        7.647059            7.0           6.0  ...        3.051602
# 2       10.705882           11.0           9.0  ...        3.374558
# 3        4.206897            4.0           3.0  ...        2.907696
# 4        2.729167            2.0           1.0  ...        2.686679
# ...           ...            ...           ...  ...             ...
# 4495     0.160000            0.0           0.0  ...        0.634310
# 4496     4.122449            4.0           3.0  ...        3.017961
# 4497     2.784314            3.0           2.0  ...        2.478563
# 4498    22.583942           23.0          19.0  ...        4.022536
# 4499    25.112903           25.0          22.0  ...        4.122713
#
#       normalized_min_clique_size  normalized_max_clique_size  \
# 0                       0.052632                    0.157895
# 1                       0.029412                    0.117647
# 2                       0.014706                    0.058824
# 3                       0.017241                    0.051724
# 4                       0.010417                    0.031250
# ...                          ...                         ...
# 4495                    0.040000                    0.080000
# 4496                    0.010204                    0.030612
# 4497                    0.019608                    0.039216
# 4498                    0.007299                    0.036496
# 4499                    0.008065                    0.040323
#
#       normalized_median_clique_size  normalized_q0.25_clique_size  \
# 0                          0.052632                      0.052632
# 1                          0.058824                      0.058824
# 2                          0.029412                      0.029412
# 3                          0.034483                      0.017241
# 4                          0.020833                      0.010417
# ...                             ...                           ...
# 4495                       0.040000                      0.040000
# 4496                       0.020408                      0.010204
# 4497                       0.039216                      0.019608
# 4498                       0.021898                      0.014599
# 4499                       0.024194                      0.016129
#
#       normalized_q0.75_clique_size  \
# 0                         0.105263
# 1                         0.088235
# 2                         0.044118
# 3                         0.034483
# 4                         0.020833
# ...                            ...
# 4495                      0.040000
# 4496                      0.020408
# 4497                      0.039216
# 4498                      0.021898
# 4499                      0.024194
#
#       normalized_variation_coefficient_clique_size  \
# 0                                         0.397478
# 1                                         0.324626
# 2                                         0.301528
# 3                                         0.319693
# 4                                         0.330712
# ...                                            ...
# 4495                                      0.248475
# 4496                                      0.305481
# 4497                                      0.313072
# 4498                                      0.261367
# 4499                                      0.257049
#
#       normalized_entropy_clique_size               target_time  \
# 0                           0.059110                       dfs
# 1                           0.046827         best_first_search
# 2                           0.022069         best_first_search
# 3                           0.020953         best_first_search
# 4                           0.011580      bidirectional_search
# ...                              ...                       ...
# 4495                        0.015238  randomized_shortest_path
# 4496                        0.011343      bidirectional_search
# 4497                        0.019226                       dfs
# 4498                        0.010864         best_first_search
# 4499                        0.012609         best_first_search
#
#                   target_space
# 0                          dfs
# 1            best_first_search
# 2            best_first_search
# 3                        astar
# 4         bidirectional_search
# ...                        ...
# 4495  randomized_shortest_path
# 4496         best_first_search
# 4497         best_first_search
# 4498                     astar
# 4499         best_first_search
#
# [4500 rows x 22 columns]

# %%
# drop all best_first_search
df_train = df_train[df_train["target_time"] != "best_first_search"]
len(df_train)
# Out:
# 1441

# %%
found_labels_in_df = df_train.iloc[:, 20].squeeze().unique().tolist()
print("Found labels:", found_labels_in_df)

encoder_labels = {'bidirectional_search': 0,
                  'dfs': 1, 'dijkstra': 2,
                  'bfs': 3,
                  'randomized_shortest_path': 4,
                  'astar': 5}

df_train.replace({"target_time": encoder_labels}, inplace=True)

df_train.head()
# Out:
# Found labels: ['dfs', 'bidirectional_search', 'bfs', 'dijkstra', 'randomized_shortest_path', 'astar']
# C:\Users\MAX\AppData\Local\Temp\ipykernel_2712\4193142512.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.replace({"target_time": encoder_labels}, inplace=True)
#     nodes  edges  ratio_n_m  ratio_m_n   density  min_degree  max_degree  \
# 0      19     11   1.727273   0.578947  0.064327           0           3
# 4      96    131   0.732824   1.364583  0.028728           0           9
# 5      18      2   9.000000   0.111111  0.013072           0           1
# 7      31     19   1.631579   0.612903  0.040860           0           4
# 12     11      1  11.000000   0.090909  0.018182           0           1
#
#     mean_degree  median_degree  q0.25_degree  ...  entropy_degree  \
# 0      1.157895            1.0           0.0  ...        1.871019
# 4      2.729167            2.0           1.0  ...        2.686679
# 5      0.222222            0.0           0.0  ...        0.764205
# 7      1.225806            1.0           0.0  ...        2.049237
# 12     0.181818            0.0           0.0  ...        0.684038
#
#     normalized_min_clique_size  normalized_max_clique_size  \
# 0                     0.052632                    0.157895
# 4                     0.010417                    0.031250
# 5                     0.055556                    0.111111
# 7                     0.032258                    0.096774
# 12                    0.090909                    0.181818
#
#     normalized_median_clique_size  normalized_q0.25_clique_size  \
# 0                        0.052632                      0.052632
# 4                        0.020833                      0.010417
# 5                        0.055556                      0.055556
# 7                        0.032258                      0.032258
# 12                       0.090909                      0.090909
#
#     normalized_q0.75_clique_size  \
# 0                       0.105263
# 4                       0.020833
# 5                       0.055556
# 7                       0.064516
# 12                      0.090909
#
#     normalized_variation_coefficient_clique_size  \
# 0                                       0.397478
# 4                                       0.330712
# 5                                       0.279812
# 7                                       0.398253
# 12                                      0.266469
#
#     normalized_entropy_clique_size  target_time          target_space
# 0                         0.059110            1                   dfs
# 4                         0.011580            0  bidirectional_search
# 5                         0.026055            1                   dfs
# 7                         0.037303            1                   dfs
# 12                        0.037620            1                   dfs
#
# [5 rows x 22 columns]

# %%
print(len(df_train))
df_train.dropna(inplace=True)
print(len(df_train))
# Out:
# 1441
# 1441
# C:\Users\MAX\AppData\Local\Temp\ipykernel_2712\2586814334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train.dropna(inplace=True)

# %%
from sklearn.ensemble import RandomForestClassifier

rfclassif=RandomForestClassifier(n_estimators=2,criterion="entropy",max_depth=3, bootstrap=True, n_jobs=4)
rfclassif.fit(df_train.iloc[:,0:20].to_numpy(), df_train.iloc[:,20].to_numpy())
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=3, n_estimators=2,
#                        n_jobs=4)

# %% [markdown]
# ## Test

# %%
test_df = pd.read_pickle("./df_test_W_meta_metrics.pkl")
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 22 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   nodes                                         500 non-null    int64
#  1   edges                                         500 non-null    int64
#  2   ratio_n_m                                     500 non-null    float64
#  3   ratio_m_n                                     500 non-null    float64
#  4   density                                       500 non-null    float64
#  5   min_degree                                    500 non-null    int64
#  6   max_degree                                    500 non-null    int64
#  7   mean_degree                                   500 non-null    float64
#  8   median_degree                                 500 non-null    float64
#  9   q0.25_degree                                  500 non-null    float64
#  10  q0.75_degree                                  500 non-null    float64
#  11  variation_coefficient_degree                  500 non-null    float64
#  12  entropy_degree                                500 non-null    float64
#  13  normalized_min_clique_size                    500 non-null    float64
#  14  normalized_max_clique_size                    500 non-null    float64
#  15  normalized_median_clique_size                 500 non-null    float64
#  16  normalized_q0.25_clique_size                  500 non-null    float64
#  17  normalized_q0.75_clique_size                  500 non-null    float64
#  18  normalized_variation_coefficient_clique_size  500 non-null    float64
#  19  normalized_entropy_clique_size                500 non-null    float64
#  20  target_time                                   500 non-null    object
#  21  target_space                                  500 non-null    object
# dtypes: float64(16), int64(4), object(2)
# memory usage: 86.1+ KB

# %%
# drop all best_first_search
test_df = test_df[test_df["target_time"] != "best_first_search"]
len(df_train)
# Out:
# 1441

# %%
test_df.replace({"target_time":encoder_labels}, inplace=True)
test_df.head()
# Out:
#     nodes  edges  ratio_n_m  ratio_m_n   density  min_degree  max_degree  \
# 2      30     83   0.361446   2.766667  0.190805           2          10
# 4     105    141   0.744681   1.342857  0.025824           0           9
# 10    158    272   0.580882   1.721519  0.021930           0           9
# 14     31     81   0.382716   2.612903  0.174194           2           8
# 15     24     29   0.827586   1.208333  0.105072           0           5
#
#     mean_degree  median_degree  q0.25_degree  ...  entropy_degree  \
# 2      5.533333            5.5          4.00  ...        2.806239
# 4      2.685714            2.0          1.00  ...        2.702194
# 10     3.443038            3.0          2.00  ...        2.768246
# 14     5.225806            5.0          3.50  ...        2.671264
# 15     2.416667            2.5          1.75  ...        2.182932
#
#     normalized_min_clique_size  normalized_max_clique_size  \
# 2                     0.033333                    0.100000
# 4                     0.009524                    0.028571
# 10                    0.006329                    0.018987
# 14                    0.032258                    0.096774
# 15                    0.041667                    0.125000
#
#     normalized_median_clique_size  normalized_q0.25_clique_size  \
# 2                        0.066667                      0.066667
# 4                        0.019048                      0.009524
# 10                       0.012658                      0.006329
# 14                       0.064516                      0.064516
# 15                       0.083333                      0.041667
#
#     normalized_q0.75_clique_size  \
# 2                       0.066667
# 4                       0.019048
# 10                      0.012658
# 14                      0.064516
# 15                      0.083333
#
#     normalized_variation_coefficient_clique_size  \
# 2                                       0.322118
# 4                                       0.330766
# 10                                      0.302662
# 14                                      0.320045
# 15                                      0.352734
#
#     normalized_entropy_clique_size  target_time          target_space
# 2                         0.045542            0     best_first_search
# 4                         0.010532            0  bidirectional_search
# 10                        0.006427            0  bidirectional_search
# 14                        0.042368            0     best_first_search
# 15                        0.049284            0     best_first_search
#
# [5 rows x 22 columns]

# %%
print(len(test_df))
test_df.dropna(inplace=True)
print(len(test_df))
# Out:
# 145
# 145

# %%
y_tilde = rfclassif.predict(test_df.iloc[:,0:20].to_numpy())

# %%
y = test_df.iloc[:,20]

# %%
acc=sum([1 for x,y in zip(y_tilde, y) if x==y])/len(y)
print(f"Accuracy: {acc*100}%")
# Out:
# Accuracy: 68.27586206896552%

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score

c_mat=confusion_matrix(y,y_tilde, normalize="true")
disp=ConfusionMatrixDisplay(c_mat)
disp.plot()

print("F1-score:", f1_score(y, y_tilde, average="weighted"))
# Out:
# F1-score: 0.6328872668288726

# %%
import pickle
from datetime import datetime as dt

ts = dt.now().strftime("%Y-%m-%d-%H-%M")
print(ts)
with open(f"./models/{ts}_{int(acc*100)}accuracy_random_forest_second_level.pkl", mode="wb") as f:
    pickle.dump(rfclassif, f)
# Out:
# 2023-12-19-18-54
